# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('student-por.csv',sep=';')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
plt.figure(figsize=(9,9))
b = sns.heatmap(df.describe().T,annot=True,linecolor='orange',linewidths=7)
print(b)
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
def count_plot():
    for i in df.select_dtypes(include=['object']):
        plt.figure(figsize=(7,7))
        count = sns.countplot(df[i])
        plt.xlabel(i)
count_plot()

# %%
def dist_plot():
    for i in df.select_dtypes(include=['number']):
        plt.figure(figsize=(7,7))
        d = sns.distplot(df[i])
dist_plot()

# %%
def hist():
    for i in df.select_dtypes(include=['number']):
        plt.figure(figsize=(7,7))
        h = plt.hist(df[i],edgecolor='black',linewidth=2)
        plt.xlabel(i)
hist()

# %%
def box_plot():
    for i in df.select_dtypes(include=['number']):
        plt.figure(figsize=(7,7))
        b = sns.boxplot(df[i])
        plt.xlabel(i)
box_plot()

# %%
df = df[['G1','G2','G3','absences','activities','paid','failures','studytime']]
df.head()
# Out:
#    G1  G2  G3  absences activities paid  failures  studytime
# 0   0  11  11         4         no   no         0          2
# 1   9  11  11         2         no   no         0          2
# 2  12  13  12         6         no   no         0          2
# 3  14  14  14         0        yes   no         0          3
# 4  11  13  13         0         no   no         0          2

# %%
df['activities'].value_counts()
# Out:
# no     334
# yes    315
# Name: activities, dtype: int64

# %%
df['activities'] = df['activities'].replace({'no': 0,'yes': 1})
df['activities']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 644    1
# 645    0
# 646    1
# 647    0
# 648    0
# Name: activities, Length: 649, dtype: int64

# %%
df['paid'].value_counts()
# Out:
# no     610
# yes     39
# Name: paid, dtype: int64

# %%
df['paid'] = df['paid'].replace({'no':0,'yes':1})
df['paid']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 644    0
# 645    0
# 646    0
# 647    0
# 648    0
# Name: paid, Length: 649, dtype: int64

# %%
df.corr()
# Out:
#                   G1        G2        G3  absences  activities      paid  \
# G1          1.000000  0.864982  0.826387 -0.147149    0.080123 -0.062784
# G2          0.864982  1.000000  0.918548 -0.124745    0.067154 -0.033925
# G3          0.826387  0.918548  1.000000 -0.091379    0.059791 -0.054898
# absences   -0.147149 -0.124745 -0.091379  1.000000   -0.015115 -0.035959
# activities  0.080123  0.067154  0.059791 -0.015115    1.000000  0.065781
# paid       -0.062784 -0.033925 -0.054898 -0.035959    0.065781  1.000000
# failures   -0.384210 -0.385782 -0.393316  0.122779    0.000561  0.069416
# studytime   0.260875  0.240498  0.249789 -0.118389    0.070080 -0.002314
#
#             failures  studytime
# G1         -0.384210   0.260875
# G2         -0.385782   0.240498
# G3         -0.393316   0.249789
# absences    0.122779  -0.118389
# activities  0.000561   0.070080
# paid        0.069416  -0.002314
# failures    1.000000  -0.147441
# studytime  -0.147441   1.000000

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(['G3'],axis=1)
Y = df['G3']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
X
# Out:
#            G1        G2  absences  activities      paid  failures  studytime
# 0   -4.155470 -0.195820  0.073433   -0.971140 -0.252853 -0.374305   0.083653
# 1   -0.874570 -0.195820 -0.357863   -0.971140 -0.252853 -0.374305   0.083653
# 2    0.219064  0.491137  0.504730   -0.971140 -0.252853 -0.374305   0.083653
# 3    0.948153  0.834615 -0.789159    1.029717 -0.252853 -0.374305   1.290114
# 4   -0.145481  0.491137 -0.789159   -0.971140 -0.252853 -0.374305   0.083653
# ..        ...       ...       ...         ...       ...       ...        ...
# 644 -0.510025 -0.195820  0.073433    1.029717 -0.252853  1.312667   1.290114
# 645  1.312697  1.178093  0.073433   -0.971140 -0.252853 -0.374305   0.083653
# 646 -0.145481  0.147659  0.504730    1.029717 -0.252853 -0.374305   0.083653
# 647 -0.510025 -0.539298  0.504730   -0.971140 -0.252853 -0.374305  -1.122808
# 648 -0.510025 -0.195820  0.073433   -0.971140 -0.252853 -0.374305  -1.122808
#
# [649 rows x 7 columns]

# %%
Y
# Out:
# 0      11
# 1      11
# 2      12
# 3      14
# 4      13
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: G3, Length: 649, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(y_pred)
print("|--------|")
print(r2_score(y_test,y_pred))
# Out:
# [ 7.43408846 14.52154982 16.56281755 10.19227338  8.90709586 12.58152623
#  12.92348368 18.58365465 12.14847568 11.53111272 10.73038685 10.33689809
#  13.42496781  8.26413927 18.57857913 12.44961458 12.71504775 12.38580337
#  10.36578987 10.25608459 12.53042808 10.12763859 17.59197683 13.26270039
#  12.28117362  0.50396488 12.3569116  13.26270039 11.23143782 12.36116353
#  13.55194982 16.55321566 13.11425691 16.20550499 12.68958433  8.90627228
#   9.4490281  11.33538987 12.62152119 11.09980227 15.57196332 17.46435441
#  11.27157866 13.29159217 12.14847568  9.47110426 12.53042808  9.12679204
#  11.41030426  8.96149214  5.80951717 14.74616445  9.36647451 12.2922768
#   6.74163406 11.18325782 11.48001458 11.51072482 14.41692006 14.52154982
#  13.08233266  7.34098583 11.4145562   8.84246107 13.33158712 12.57042304
#  11.607637   13.43621688 14.6142528   6.30876056  7.80219695 11.26268437
#  13.47621184 10.29607955 14.38200063 13.58084159 13.82844888 11.45112281
# ...

# %%
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 0.8016505072595621
# 1.228989195241602
# 1.1085978509999026

# %%
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
y_dt = dt.predict(X_test)
print(y_dt)
print("|--------|")
print(r2_score(y_test,y_dt))
# Out:
# [ 9.         16.         17.         10.33333333  9.         12.
#  13.         18.         11.         11.         11.         11.
#  12.          8.         17.         13.         12.         12.5
#  10.         10.33333333 12.5        11.         17.5        13.5
#  12.          0.         12.75       13.5        12.         13.
#  13.         17.         14.         17.         14.         11.
#   8.         12.5        13.         11.         15.5        17.
#  12.         13.66666667 11.         11.         12.5         9.
#  11.         10.          7.         15.         11.         12.
#   8.         10.         12.         10.         13.         16.
#  12.          8.         12.         10.         14.         12.
#  10.         14.         14.          0.          7.         11.
#  14.         11.         14.         14.         13.         11.
#  14.         14.         15.         10.         11.         14.
# ...

# %%
print(mean_absolute_error(y_test,y_dt))
print(mean_squared_error(y_test,y_dt))
print(np.sqrt(mean_squared_error(y_test,y_dt)))
# Out:
# 1.0102249488752557
# 2.5353612815269257
# 1.5922817845868005

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_rf = rf.predict(X_test)
print(y_rf)
print("|--------|")
print(r2_score(y_test,y_rf))
# Out:
# [ 8.33       14.976      16.6        10.7091627   8.967      12.87
#  12.78333333 18.04833333 11.67866667 11.23       10.685      10.45938889
#  12.81        8.09       17.31833333 12.66052381 12.53       12.62183333
#  10.46938889 10.39485714 12.48766667 10.91028571 17.255      13.45378571
#  12.997       0.08       12.75217857 13.45378571 11.96       12.6005
#  13.29       16.42       13.67833333 16.47       13.02666667  9.6
#   9.51       12.4245     12.9475     10.98       15.08366667 17.31
#  11.8175     13.68128571 11.67866667 10.28983333 12.48766667 10.08
#  11.21        9.28        7.28       15.06       10.775      12.77666667
#   7.48       10.43       12.22       10.54       13.83783333 14.976
#  13.3775      7.69       11.57766667  9.86       13.74216667 12.505
#  11.2675     13.72130952 14.23        0.57333333  6.16095238 11.72
#  13.43666667 10.72283333 14.191      13.93       12.99       11.23
#  13.93       12.56583333 14.92733333 10.07       10.165      13.72130952
# ...

# %%
print(mean_absolute_error(y_test,y_rf))
print(mean_squared_error(y_test,y_rf))
print(np.sqrt(mean_squared_error(y_test,y_rf)))
# Out:
# 0.8582754406466063
# 1.6192551751588615
# 1.2724995776654944
